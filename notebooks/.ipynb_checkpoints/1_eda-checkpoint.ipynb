# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loading all dataset
df=pd.read_csv(r'C:\Users\shreyaash mogaveera\MedBot\data\dataset.csv')
desc=pd.read_csv(r'C:\Users\shreyaash mogaveera\MedBot\data\symptom_Description.csv')
precaution=pd.read_csv(r'C:\Users\shreyaash mogaveera\MedBot\data\symptom_precaution.csv')
severity=pd.read_csv(r'C:\Users\shreyaash mogaveera\MedBot\data\Symptom-severity.csv')

# %% [markdown]
# ### main dataset

# %%
print("main dataset shape:",df.shape)
print("\nColumns:",df.columns.tolist())
print("\n first few rows")
df.sample(5)
# Out:
# main dataset shape: (4920, 18)
#
# Columns: ['Disease', 'Symptom_1', 'Symptom_2', 'Symptom_3', 'Symptom_4', 'Symptom_5', 'Symptom_6', 'Symptom_7', 'Symptom_8', 'Symptom_9', 'Symptom_10', 'Symptom_11', 'Symptom_12', 'Symptom_13', 'Symptom_14', 'Symptom_15', 'Symptom_16', 'Symptom_17']
#
#  first few rows
#              Disease    Symptom_1    Symptom_2        Symptom_3  \
# 969         Jaundice      itching     vomiting          fatigue
# 2956   Drug Reaction      itching    skin_rash     stomach_pain
# 4048  Varicose veins      fatigue       cramps         bruising
# 4078     hepatitis A   joint_pain     vomiting   yellowish_skin
# 2704       Psoriasis    skin_rash   joint_pain     skin_peeling
#
#                  Symptom_4              Symptom_5               Symptom_6  \
# 969            weight_loss             high_fever          yellowish_skin
# 2956   burning_micturition    spotting_ urination                     NaN
# ...

# %%
# how many unique diseases
print("\n Unique diseases:", df['Disease'].nunique())
df['Disease'].value_counts()
# Out:
#  Unique diseases: 41
# Disease
# Fungal infection                           120
# Allergy                                    120
# GERD                                       120
# Chronic cholestasis                        120
# Drug Reaction                              120
# Peptic ulcer diseae                        120
# AIDS                                       120
# Diabetes                                   120
# Gastroenteritis                            120
# Bronchial Asthma                           120
# Hypertension                               120
# Migraine                                   120
# Cervical spondylosis                       120
# Paralysis (brain hemorrhage)               120
# Jaundice                                   120
# Malaria                                    120
# Chicken pox                                120
# Dengue                                     120
# Typhoid                                    120
# ...

# %%
#how many unique symptoms
symptom_cols=[col for col in df.columns if col.startswith('Symptom_')]
print("\n Sympton cols:",len(symptom_cols))

all_symptoms=set()
for col in symptom_cols:
    all_symptoms.update(df[col].dropna().unique())
print("\n unique symptoms:", len(all_symptoms))
# Out:
#  Sympton cols: 17
#
#  unique symptoms: 131

# %% [markdown]
# ## other datasets

# %%
print("\n Secerity dataset:")
print("\nshape:",severity.shape)
print("Symptoms with severity:", len(severity))
severity.sample(5)
# Out:
#  Secerity dataset:
#
# shape: (133, 2)
# Symptoms with severity: 133
#                      Symptom  weight
# 90        foul_smell_ofurine       5
# 86              unsteadiness       4
# 73       swollen_extremeties       5
# 6                 joint_pain       3
# 91  continuous_feel_of_urine       6

# %%
print("\n Description datset:")
print("\n shape:", desc.shape)
desc.sample(5)
# Out:
#  Description datset:
#
#  shape: (41, 2)
#                 Disease                                        Description
# 38            Arthritis  Arthritis is the swelling and tenderness of on...
# 33          Hepatitis E  A rare form of liver inflammation caused by in...
# 15  Peptic ulcer diseae  Peptic ulcer disease (PUD) is a break in the i...
# 30     Bronchial Asthma  Bronchial asthma is a medical condition which ...
# 18          Chicken pox  Chickenpox is a highly contagious disease caus...

# %%
print("Precaution dataset:")
print("\n Shape:",precaution.shape)
precaution.sample(5)
# Out:
# Precaution dataset:
#
#  Shape: (41, 5)
#                                     Disease                      Precaution_1  \
# 9   (vertigo) Paroymsal  Positional Vertigo                          lie down
# 36                             Heart attack                    call ambulance
# 0                             Drug Reaction                   stop irritation
# 39                          Gastroenteritis  stop eating solid food for while
# 33                              Hepatitis E          stop alcohol consumption
#
#                       Precaution_2               Precaution_3  \
# 9      avoid sudden change in body  avoid abrupt head movment
# 36          chew or swallow asprin                  keep calm
# 0         consult nearest hospital           stop taking drug
# 39  try taking small sips of water                       rest
# 33                            rest             consult doctor
#
#              Precaution_4
# 9                   relax
# 36                    NaN
# ...
